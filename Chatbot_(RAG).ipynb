# %%
# !pip install -U langchain-community --quiet

# %%
# !pip install "unstructured[xlsx]"

# %%
from langchain_community.document_loaders import TextLoader


loader_text = TextLoader("DATA OF PROGRAMMING LANGUAGES.txt")

docs = loader_text.load()

print(docs)
# Out:
# [Document(metadata={'source': 'DATA OF PROGRAMMING LANGUAGES.txt'}, page_content='You are an expert HTML instructor.\n\nTopics:\n- Basic structure of HTML\n- Tags (div, span, p, h1-h6, etc.)\n- Forms\n- Tables\n- Semantic HTML\n- Forms and inputs\n- Accessibility basics\n\nRules:\n- Always show full HTML examples\n- Explain tag purpose clearly\n- Provide clean structure\n\nFormat:\nDefinition:\nCode Example:\nExplanation:\n\n\n\nCSS:\n\nYou are an expert CSS and Tailwind CSS instructor.\n\nCSS Topics:\n- Selectors\n- Box model\n- Flexbox\n- Grid\n- Positioning\n- Responsive design\n\nTailwind Topics:\n- Utility classes\n- Layout\n- Colors\n- Spacing\n- Responsive utilities\n\nRules:\n- Provide both CSS and Tailwind examples when possible\n- Explain visual behavior clearly\n\nFormat:\nDefinition:\nExplanation:\nCode:\n\nJAVASCRIPT:\n\nYou are a JavaScript expert instructor.\n\nTeach JavaScript for frontend and backend development.\n\nTopics:\n- Variables (var, let, const)\n- Data type
# ...

# %%
print(docs[0].page_content)
# Out:
# You are an expert HTML instructor.
#
# Topics:
# - Basic structure of HTML
# - Tags (div, span, p, h1-h6, etc.)
# - Forms
# - Tables
# - Semantic HTML
# - Forms and inputs
# - Accessibility basics
#
# Rules:
# - Always show full HTML examples
# - Explain tag purpose clearly
# - Provide clean structure
#
# Format:
# Definition:
# Code Example:
# Explanation:
#
#
#
# CSS:
#
# You are an expert CSS and Tailwind CSS instructor.
#
# CSS Topics:
# - Selectors
# - Box model
# - Flexbox
# - Grid
# - Positioning
# - Responsive design
#
# Tailwind Topics:
# - Utility classes
# - Layout
# - Colors
# - Spacing
# - Responsive utilities
#
# Rules:
# - Provide both CSS and Tailwind examples when possible
# - Explain visual behavior clearly
#
# Format:
# Definition:
# Explanation:
# Code:
#
# JAVASCRIPT:
#
# You are a JavaScript expert instructor.
#
# Teach JavaScript for frontend and backend development.
#
# Topics:
# - Variables (var, let, const)
# - Data types
# - Functions
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,chunk_overlap=50)

chunks = splitter.split_documents(docs)

print(chunks[0].page_content)
# Out:
# You are an expert HTML instructor.
#
# Topics:
# - Basic structure of HTML
# - Tags (div, span, p, h1-h6, etc.)
# - Forms
# - Tables
# - Semantic HTML
# - Forms and inputs
# - Accessibility basics
#
# Rules:
# - Always show full HTML examples
# - Explain tag purpose clearly
# - Provide clean structure
#
# Format:
# Definition:
# Code Example:
# Explanation:
#
#
#
# CSS:
#
# You are an expert CSS and Tailwind CSS instructor.
#
# CSS Topics:
# - Selectors
# - Box model
# - Flexbox
# - Grid
# - Positioning
# - Responsive design

# %%
# %pip install -U langchain-google-genai --quiet

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-001",
    google_api_key = "AIzaSyD5skHkCAC1KjKYigcUCQghUGkevBSiIUI"

# %%
# %pip install faiss-cpu --quiet

# %%
from langchain_community.vectorstores import FAISS

vector_store = FAISS.from_documents(chunks, embeddings)

# %%
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate(
    input_variables=["context", "question"],
    template="""
Answer the question using the context below.

Context:
{context}

Question:
{question}

Answer:
Give a short answer in 2-3 lines only.
"""
)

# %%
test_prompt = prompt_template.format(
    context="Python is a programming language.",
    question="What is Python?"
)
print(test_prompt)
# Out:
# you are a helpful AI assistant and provide the answer for the question based on the context
#     context: Python is a programming language.
#     question: What is Python?
#     answer:provide a clear and concise answer based on the context above if the context does not contain enough information to answer the question, say "I don't know"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

LLM = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
    google_api_key = "AIzaSyD5skHkCAC1KjKYigcUCQghUGkevBSiIUI",
    temperature = 0.5,
       max_retries=2,
    convert_system_message_to_human = True
)

response=LLM.invoke("python is high level language?  ")
print(response.content)
# Out:
# **Yes, absolutely!**
#
# Python is a quintessential example of a **high-level programming language**.
#
# Here's why:
#
# 1.  **Abstraction from Hardware:** Python abstracts away most of the complex details of the computer's hardware (like memory management, CPU registers, etc.). You don't need to worry about how data is stored in memory at a low level; Python handles it for you.
#
# 2.  **Readability and Simplicity:** Its syntax is designed to be very close to human language (English), making it easy to read, write, and understand. This reduces the cognitive load on the programmer.
#
# 3.  **Automatic Memory Management:** Python uses automatic garbage collection, meaning you don't have to manually allocate and deallocate memory. This prevents many common programming errors and makes development faster.
#
# 4.  **Portability:** Python code can run on various operating systems (Windows, macOS, Linux, etc.) with little to no modification, thanks to its interpreter.
#
# ...

# %%
def rag(query):

    docs = retriever.invoke(query)

    if not docs:
        return "No relevant documents found"

    context = "\n\n".join(doc.page_content for doc in docs)

    prompt = prompt_template.format(
        context=context,
        question=query
    )

    response = LLM.invoke(prompt)

    return response.content

# %%
rag("what is python")
# Out:
# 'Python is a high-level, interpreted, general-purpose programming language known for its clear syntax and readability. It supports multiple programming paradigms and boasts a vast ecosystem of libraries, making it highly versatile for various applications from web development to data science.'

# %%
# !pip install -U langchain-community --quiet

# !pip install "unstructured[xlsx]"

from langchain_community.document_loaders import TextLoader


loader_text = TextLoader("DATA OF PROGRAMMING LANGUAGES.txt")

docs = loader_text.load()

print(docs)

print(docs[0].page_content)

from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,chunk_overlap=50)

chunks = splitter.split_documents(docs)

print(chunks[0].page_content)

# %pip install -U langchain-google-genai --quiet

from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-001",
    google_api_key = "AIzaSyCuwSUhBhKKaq_QxSmD7Q9kYXcAImeW7gs"

    )
# %pip install faiss-cpu --quiet

from langchain_community.vectorstores import FAISS

vector_store = FAISS.from_documents(chunks, embeddings)

from re import search
retriever = vector_store.as_retriever(
    search_type="similarity",
    k=3
)

from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate(
    input_variables=["context", "question"],
    template="""
Answer the question using the context below.

Context:
{context}

Question:
{question}

Answer:
Give a short answer in 2-3 lines only.
"""
)

text_prompt = prompt_template.format(
    context=chunks,
    question="what is python"
)

from langchain_google_genai import ChatGoogleGenerativeAI

LLM = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
    google_api_key = "AIzaSyD5skHkCAC1KjKYigcUCQghUGkevBSiIUI",
    temperature = 0.5,
       max_retries=2,
    convert_system_message_to_human = True
)

response=LLM.invoke("just tell me is python is high level language? and where we use it enlist areas ")
print(response.content)

def rag(query):

 docs = retriever.invoke(query)
 context="\n\n".join(doc.page_content for doc in docs)

 prompt = prompt_template.format(context=context, question=query)

 response = LLM.invoke(prompt)
 answer = response.content

 return answer
# Out:
# ...
# [Document(metadata={'source': 'DATA OF PROGRAMMING LANGUAGES.txt'}, page_content='You are an expert HTML instructor.\n\nTopics:\n- Basic structure of HTML\n- Tags (div, span, p, h1-h6, etc.)\n- Forms\n- Tables\n- Semantic HTML\n- Forms and inputs\n- Accessibility basics\n\nRules:\n- Always show full HTML examples\n- Explain tag purpose clearly\n- Provide clean structure\n\nFormat:\nDefinition:\nCode Example:\nExplanation:\n\n\n\nCSS:\n\nYou are an expert CSS and Tailwind CSS instructor.\n\nCSS Topics:\n- Selectors\n- Box model\n- Flexbox\n- Grid\n- Positioning\n- Responsive design\n\nTailwind Topics:\n- Utility classes\n- Layout\n- Colors\n- Spacing\n- Responsive utilities\n\nRules:\n- Provide both CSS and Tailwind examples when possible\n- Explain visual behavior clearly\n\nFormat:\nDefinition:\nExplanation:\nCode:\n\nJAVASCRIPT:\n\nYou are a JavaScript expert instructor.\n\nTeach JavaScript for frontend and backend development.\n\nTopics:\n- Variables (var, let, const)\n- Data type
# ...

# %%
rag("tell me html in 1 line ")
# Out:
# 'HTML (HyperText Markup Language) is the standard markup language used to create web pages. It provides the structure and content for everything you see on the internet, using a system of tags to define elements like headings, paragraphs, images, and links.'
